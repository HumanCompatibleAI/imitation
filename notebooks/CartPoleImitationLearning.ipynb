# %%
# %load_ext autoreload
# %autoreload 2
from matplotlib import pyplot as plt
import yairl
import yairl.scripts as scripts
import yairl.util as util

# %%
scripts.plot_fight_loss(n_epochs=500, n_disc_steps_per_plot=10, n_gen_steps_per_plot=10000, 
                        n_rollout_samples=4000, n_plots_each_per_epoch=10,
                        n_gen_plot_episodes=10)
# Out:
# epoch:   0%|          | 0/500 [00:00<?, ?it/s]
# epoch:   0%|          | 1/500 [02:10<18:04:08, 130.36s/it]
# epoch:   0%|          | 2/500 [04:08<17:32:33, 126.81s/it]
# epoch:   1%|          | 3/500 [06:04<17:03:26, 123.55s/it]
# epoch:   1%|          | 4/500 [08:27<17:49:17, 129.35s/it]
# epoch:   1%|          | 5/500 [10:47<18:13:51, 132.59s/it]
# epoch:   1%|          | 6/500 [13:19<18:58:27, 138.28s/it]
# epoch:   1%|▏         | 7/500 [15:30<18:38:11, 136.09s/it]
# epoch:   2%|▏         | 8/500 [17:46<18:35:11, 136.00s/it]
# epoch:   2%|▏         | 9/500 [20:01<18:30:53, 135.75s/it]
# epoch:   2%|▏         | 10/500 [23:08<20:33:56, 151.09s/it]
# epoch:   2%|▏         | 11/500 [26:13<21:53:58, 161.22s/it]
# epoch:   2%|▏         | 12/500 [28:52<21:47:46, 160.79s/it]
# epoch:   3%|▎         | 13/500 [32:01<22:53:19, 169.20s/it]
# epoch:   3%|▎         | 14/500 [35:04<23:24:17, 173.37s/it]
# epoch:   3%|▎         | 15/500 [37:25<22:01:40, 163.51s/it]
# epoch:   3%|▎         | 16/500 [39:41<20:52:34, 155.28s/it]
# epoch:   3%|▎         | 17/500 [41:52<19:52:18, 148.11s/it]
# epoch:   4%|▎         | 18/500 [44:08<19:20:10, 144.42s/it]
# epoch:   4%|▍         | 19/500 [46:27<19:03:43, 142.67s/it]
# epoch:   4%|▍         | 20/500 [48:40<18:40:05, 140.01s/it]
# epoch:   4%|▍         | 21/500 [50:55<18:24:17, 138.33s/it]
# epoch:   4%|▍         | 22/500 [53:07<18:07:54, 136.56s/it]
# epoch:   5%|▍         | 23/500 [55:33<18:27:08, 139.26s/it]
# epoch:   5%|▍         | 24/500 [58:27<19:47:17, 149.66s/it]
# epoch:   5%|▌         | 25/500 [1:00:48<19:25:02, 147.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-66e612bf45cd> in <module>
#       1 scripts.plot_fight_loss(n_epochs=500, n_disc_steps_per_plot=10, n_gen_steps_per_plot=10000,
#       2                         n_rollout_samples=4000, n_plots_each_per_epoch=10,
# ----> 3                         n_gen_plot_episodes=10)
#
# ~/Documents/yairl/yairl/scripts.py in plot_fight_loss(env, n_epochs, n_plots_each_per_epoch, n_disc_steps_per_plot, n_gen_steps_per_plot, n_rollout_samples, n_gen_plot_episodes, trainer_hook_fn, trainer, interactive)
#     217             add_plot_disc(False)
#     218         for _ in range(n_plots_each_per_epoch):
# --> 219             epoch(True)
#     220             add_plot_disc(True)
#     221         add_plot_gen()
#
# ~/Documents/yairl/yairl/scripts.py in epoch(gen_mode)
#     158         nonlocal plot_idx
#     159         if gen_mode:
# --> 160             trainer.train_gen(n_steps=n_gen_steps_per_plot)
#     161         else:
#     162             trainer.train_disc(n_steps=n_disc_steps_per_plot)
#
# ~/Documents/yairl/yairl/airl.py in train_gen(self, n_steps)
#     106     def train_gen(self, n_steps=10000):
#     107         self.gen_policy.set_env(self.env)  # Can't guarantee that env is the same.
# --> 108         self.gen_policy.learn(n_steps)
#     109
#     110     def train(self, *, n_epochs=100, n_gen_steps_per_epoch=None,
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py in learn(self, total_timesteps, callback, seed, log_interval, tb_log_name, reset_num_timesteps)
#     283                 cliprangenow = self.cliprange(frac)
#     284                 # true_reward is the reward without discount
# --> 285                 obs, returns, masks, actions, values, neglogpacs, states, ep_infos, true_reward = runner.run()
#     286                 ep_info_buf.extend(ep_infos)
#     287                 mb_loss_vals = []
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/stable_baselines/ppo2/ppo2.py in run(self)
#     422             if isinstance(self.env.action_space, gym.spaces.Box):
#     423                 clipped_actions = np.clip(actions, self.env.action_space.low, self.env.action_space.high)
# --> 424             self.obs[:], rewards, self.dones, infos = self.env.step(clipped_actions)
#     425             for info in infos:
#     426                 maybe_ep_info = info.get('episode')
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/stable_baselines/common/vec_env/base_vec_env.py in step(self, actions)
#      92         """
#      93         self.step_async(actions)
# ---> 94         return self.step_wait()
#      95
#      96     def get_images(self):
#
# ~/Documents/yairl/yairl/airl.py in step_wait(self)
#     358     def step_wait(self):
#     359         obs, rew, done, info = self.venv.step_wait()
# --> 360         rew = self.reward_fn(self._old_obs, self._actions, obs)
#     361         # XXX: We never get to see episode end. (See Issue #1).
#     362         # Therefore, the final obs of every episode is incorrect.
#
# ~/Documents/yairl/yairl/airl.py in R(old_obs, act, new_obs)
#     290             # Calculate generator-policy log probabilities.
#     291             log_act_prob = np.log(self.gen_policy.action_probability(
# --> 292                 old_obs, actions=act)).flatten()  # (N,)
#     293             assert len(log_act_prob) == n_gen
#     294
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/stable_baselines/common/base_class.py in action_probability(self, observation, state, mask, actions)
#     388
#     389         observation = observation.reshape((-1,) + self.observation_space.shape)
# --> 390         actions_proba = self.proba_step(observation, state, mask)
#     391
#     392         if len(actions_proba) == 0:  # empty list means not implemented
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/stable_baselines/common/policies.py in proba_step(self, obs, state, mask)
#     454
#     455     def proba_step(self, obs, state=None, mask=None):
# --> 456         return self.sess.run(self.policy_proba, {self.obs_ph: obs})
#     457
#     458     def value(self, obs, state=None, mask=None):
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/yairl/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
