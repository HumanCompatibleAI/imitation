# %%
# %load_ext autoreload
# %autoreload 2
import yairl
import scripts

# %%
scripts.plot_fight_loss(n_epochs=20)
# Out:
# > /root/home/yairl/scripts.py(186)plot_fight_loss()
#     185     import ipdb; ipdb.set_trace()
# --> 186     trainer = _init_trainer(env, use_expert_rollouts=True)
#     187     n_timesteps = len(trainer.expert_obs_old)
#
# ipdb> c
# plot idx (dis): 0
# disc loss: 1517.0029296875
# ...
# plot idx (dis): 1
# disc loss: 1232.369873046875
# plot idx (dis): 2
# disc loss: 1088.724853515625
# plot idx (dis): 3
# disc loss: 988.7031860351562
# plot idx (dis): 4
# disc loss: 910.7568359375
# plot idx (dis): 5
# disc loss: 910.8109130859375
# plot idx (dis): 6
# disc loss: 841.22998046875
# plot idx (dis): 7
# disc loss: 799.885009765625
# plot idx (dis): 8
# disc loss: 832.7596435546875
# plot idx (dis): 9
# disc loss: 778.8306884765625
# plot idx (dis): 10
# disc loss: 811.1373291015625
# plot idx (dis): 11
# disc loss: 831.5789794921875
# plot idx (dis): 12
# disc loss: 801.865966796875
# plot idx (dis): 13
# disc loss: 788.7100830078125
# plot idx (dis): 14
# disc loss: 736.3585205078125
# ...

# %%
print("hello")
