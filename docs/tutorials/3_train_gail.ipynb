# %% [markdown]
# [download this notebook here](https://github.com/HumanCompatibleAI/imitation/blob/master/docs/tutorials/3_train_gail.ipynb)
# # Train an Agent using Generative Adversarial Imitation Learning
#
# The idea of generative adversarial imitation learning is to train a discriminator network to distinguish between expert trajectories and learner trajectories.
# The learner is trained using a traditional reinforcement learning algorithm such as PPO and is rewarded for trajectories that make the discriminator think that it was an expert trajectory.

# %% [markdown]
# As usual, we first need an expert. Again, we download one from the HuggingFace model hub for convenience.
#
# Note that we use a variant of the CartPole environment from the seals package, which has fixed episode durations. Read more about why we do this [here](https://imitation.readthedocs.io/en/latest/main-concepts/variable_horizon.html).

# %%
import numpy as np
from imitation.policies.serialize import load_policy
from imitation.util.util import make_vec_env
from imitation.data.wrappers import RolloutInfoWrapper

SEED = 42

env = make_vec_env(
    "seals:seals/CartPole-v0",
    rng=np.random.default_rng(SEED),
    n_envs=8,
    post_wrappers=[
        lambda env, _: RolloutInfoWrapper(env)
    ],  # needed for computing rollouts later
)
expert = load_policy(
    "ppo-huggingface",
    organization="HumanCompatibleAI",
    env_name="seals:seals/CartPole-v0",
    venv=env,
)
# Out:
# /home/vincentwang/.local/lib/python3.10/site-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /home/vincentwang/.local/lib/python3.10/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %% [markdown]
# We generate some expert trajectories, that the discriminator needs to distinguish from the learner's trajectories.

# %%
from imitation.data import rollout

rollouts = rollout.rollout(
    expert,
    env,
    rollout.make_sample_until(min_timesteps=None, min_episodes=60),
    rng=np.random.default_rng(SEED),
)

# %% [markdown]
# Now we are ready to set up our GAIL trainer.
# Note, that the `reward_net` is actually the network of the discriminator.
# We evaluate the learner before and after training so we can see if it made any progress.

# %%
from imitation.algorithms.adversarial.gail import GAIL
from imitation.rewards.reward_nets import BasicRewardNet
from imitation.util.networks import RunningNorm
from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.evaluation import evaluate_policy

learner = PPO(
    env=env,
    policy=MlpPolicy,
    batch_size=64,
    ent_coef=0.0,
    learning_rate=0.0004,
    gamma=0.95,
    n_epochs=5,
    seed=SEED,
)
reward_net = BasicRewardNet(
    observation_space=env.observation_space,
    action_space=env.action_space,
    normalize_input_layer=RunningNorm,
)
gail_trainer = GAIL(
    demonstrations=rollouts,
    demo_batch_size=1024,
    gen_replay_buffer_capacity=512,
    n_disc_updates_per_round=8,
    venv=env,
    gen_algo=learner,
    reward_net=reward_net,
)

# evaluate the learner before training
env.seed(SEED)
learner_rewards_before_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True
)

# train the learner and evaluate again
gail_trainer.train(200_000)
env.seed(SEED)
learner_rewards_after_training, _ = evaluate_policy(
    learner, env, 100, return_episode_rewards=True
)
# Out:
# round:   0%|          | 0/12 [00:00<?, ?it/s]
# ------------------------------------------
# | raw/                        |          |
# |    gen/rollout/ep_len_mean  | 500      |
# |    gen/rollout/ep_rew_mean  | 34.4     |
# |    gen/time/fps             | 3203     |
# |    gen/time/iterations      | 1        |
# |    gen/time/time_elapsed    | 5        |
# |    gen/time/total_timesteps | 16384    |
# ------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.685    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.683    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.681    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.675    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.678    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 1        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 34.4     |
# |    gen/time/fps                     | 3.2e+03  |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 5        |
# |    gen/time/total_timesteps         | 1.64e+04 |
# |    gen/train/approx_kl              | 0.00699  |
# |    gen/train/clip_fraction          | 0.0338   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.687   |
# |    gen/train/explained_variance     | 0.0555   |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0315   |
# |    gen/train/n_updates              | 5        |
# |    gen/train/policy_gradient_loss   | -0.00158 |
# |    gen/train/value_loss             | 4.7      |
# --------------------------------------------------
# round:   8%|▊         | 1/12 [00:10<01:54, 10.42s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 35.3        |
# |    gen/rollout/ep_rew_wrapped_mean | 270         |
# |    gen/time/fps                    | 3430        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 4           |
# |    gen/time/total_timesteps        | 32768       |
# |    gen/train/approx_kl             | 0.006985888 |
# |    gen/train/clip_fraction         | 0.0338      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.687      |
# |    gen/train/explained_variance    | 0.0555      |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0315      |
# |    gen/train/n_updates             | 5           |
# |    gen/train/policy_gradient_loss  | -0.00158    |
# |    gen/train/value_loss            | 4.7         |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.679    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.677    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.674    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.69     |
# |    disc/disc_loss                   | 0.675    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 2        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 35.3     |
# |    gen/rollout/ep_rew_wrapped_mean  | 270      |
# |    gen/time/fps                     | 3.43e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 4        |
# |    gen/time/total_timesteps         | 3.28e+04 |
# |    gen/train/approx_kl              | 0.00869  |
# |    gen/train/clip_fraction          | 0.0643   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.677   |
# |    gen/train/explained_variance     | 0.728    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0786   |
# |    gen/train/n_updates              | 10       |
# |    gen/train/policy_gradient_loss   | -0.00239 |
# |    gen/train/value_loss             | 0.26     |
# --------------------------------------------------
# round:  17%|█▋        | 2/12 [00:20<01:41, 10.13s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 33.2        |
# |    gen/rollout/ep_rew_wrapped_mean | 284         |
# |    gen/time/fps                    | 4052        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 4           |
# |    gen/time/total_timesteps        | 49152       |
# |    gen/train/approx_kl             | 0.008685788 |
# |    gen/train/clip_fraction         | 0.0643      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.677      |
# |    gen/train/explained_variance    | 0.728       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0786      |
# |    gen/train/n_updates             | 10          |
# |    gen/train/policy_gradient_loss  | -0.00239    |
# |    gen/train/value_loss            | 0.26        |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.672    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.689    |
# |    disc/disc_loss                   | 0.673    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.67     |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.667    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.666    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.663    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.669    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 3        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 33.2     |
# |    gen/rollout/ep_rew_wrapped_mean  | 284      |
# |    gen/time/fps                     | 4.05e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 4        |
# |    gen/time/total_timesteps         | 4.92e+04 |
# |    gen/train/approx_kl              | 0.00862  |
# |    gen/train/clip_fraction          | 0.0649   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.677   |
# |    gen/train/explained_variance     | 0.888    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0178   |
# |    gen/train/n_updates              | 15       |
# |    gen/train/policy_gradient_loss   | -0.00453 |
# |    gen/train/value_loss             | 0.0455   |
# --------------------------------------------------
# round:  25%|██▌       | 3/12 [00:29<01:25,  9.48s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 34.9        |
# |    gen/rollout/ep_rew_wrapped_mean | 278         |
# |    gen/time/fps                    | 3968        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 4           |
# |    gen/time/total_timesteps        | 65536       |
# |    gen/train/approx_kl             | 0.008622437 |
# |    gen/train/clip_fraction         | 0.0649      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.677      |
# |    gen/train/explained_variance    | 0.888       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.0178      |
# |    gen/train/n_updates             | 15          |
# |    gen/train/policy_gradient_loss  | -0.00453    |
# |    gen/train/value_loss            | 0.0455      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.653    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.649    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.649    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.644    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.5      |
# |    disc/disc_acc_expert             | 0        |
# |    disc/disc_acc_gen                | 1        |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0        |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.495    |
# |    disc/disc_acc_expert             | 0.00293  |
# |    disc/disc_acc_gen                | 0.987    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.637    |
# |    disc/disc_proportion_expert_pred | 0.00781  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.494    |
# |    disc/disc_acc_expert             | 0.0166   |
# |    disc/disc_acc_gen                | 0.971    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.0229   |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.499    |
# |    disc/disc_acc_expert             | 0.00244  |
# |    disc/disc_acc_gen                | 0.995    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.645    |
# |    disc/disc_proportion_expert_pred | 0.00385  |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 4        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 34.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 278      |
# |    gen/time/fps                     | 3.97e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 4        |
# |    gen/time/total_timesteps         | 6.55e+04 |
# |    gen/train/approx_kl              | 0.0139   |
# |    gen/train/clip_fraction          | 0.152    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.663   |
# |    gen/train/explained_variance     | 0.925    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.00416  |
# |    gen/train/n_updates              | 20       |
# |    gen/train/policy_gradient_loss   | -0.0128  |
# |    gen/train/value_loss             | 0.0155   |
# --------------------------------------------------
# round:  33%|███▎      | 4/12 [00:37<01:13,  9.24s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 39.9        |
# |    gen/rollout/ep_rew_wrapped_mean | 275         |
# |    gen/time/fps                    | 3383        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 4           |
# |    gen/time/total_timesteps        | 81920       |
# |    gen/train/approx_kl             | 0.013922634 |
# |    gen/train/clip_fraction         | 0.152       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.663      |
# |    gen/train/explained_variance    | 0.925       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.00416     |
# |    gen/train/n_updates             | 20          |
# |    gen/train/policy_gradient_loss  | -0.0128     |
# |    gen/train/value_loss            | 0.0155      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.51     |
# |    disc/disc_acc_expert             | 0.0518   |
# |    disc/disc_acc_gen                | 0.968    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.646    |
# |    disc/disc_proportion_expert_pred | 0.042    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.535    |
# |    disc/disc_acc_expert             | 0.139    |
# |    disc/disc_acc_gen                | 0.931    |
# |    disc/disc_entropy                | 0.686    |
# |    disc/disc_loss                   | 0.647    |
# |    disc/disc_proportion_expert_pred | 0.104    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.62     |
# |    disc/disc_acc_expert             | 0.317    |
# |    disc/disc_acc_gen                | 0.922    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.642    |
# |    disc/disc_proportion_expert_pred | 0.198    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.68     |
# |    disc/disc_acc_expert             | 0.449    |
# |    disc/disc_acc_gen                | 0.91     |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.641    |
# |    disc/disc_proportion_expert_pred | 0.27     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.692    |
# |    disc/disc_acc_expert             | 0.476    |
# |    disc/disc_acc_gen                | 0.909    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.283    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.708    |
# |    disc/disc_acc_expert             | 0.509    |
# |    disc/disc_acc_gen                | 0.908    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.637    |
# |    disc/disc_proportion_expert_pred | 0.3      |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.693    |
# |    disc/disc_acc_expert             | 0.499    |
# |    disc/disc_acc_gen                | 0.887    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.635    |
# |    disc/disc_proportion_expert_pred | 0.306    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.702    |
# |    disc/disc_acc_expert             | 0.506    |
# |    disc/disc_acc_gen                | 0.898    |
# |    disc/disc_entropy                | 0.684    |
# |    disc/disc_loss                   | 0.631    |
# |    disc/disc_proportion_expert_pred | 0.304    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.642    |
# |    disc/disc_acc_expert             | 0.368    |
# |    disc/disc_acc_gen                | 0.917    |
# |    disc/disc_entropy                | 0.685    |
# |    disc/disc_loss                   | 0.64     |
# |    disc/disc_proportion_expert_pred | 0.226    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 5        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 39.9     |
# |    gen/rollout/ep_rew_wrapped_mean  | 275      |
# |    gen/time/fps                     | 3.38e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 4        |
# |    gen/time/total_timesteps         | 8.19e+04 |
# |    gen/train/approx_kl              | 0.0125   |
# |    gen/train/clip_fraction          | 0.149    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.648   |
# |    gen/train/explained_variance     | 0.904    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | -0.0214  |
# |    gen/train/n_updates              | 25       |
# |    gen/train/policy_gradient_loss   | -0.0149  |
# |    gen/train/value_loss             | 0.0176   |
# --------------------------------------------------
# round:  42%|████▏     | 5/12 [00:47<01:05,  9.33s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 44.4        |
# |    gen/rollout/ep_rew_wrapped_mean | 271         |
# |    gen/time/fps                    | 3974        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 4           |
# |    gen/time/total_timesteps        | 98304       |
# |    gen/train/approx_kl             | 0.012476852 |
# |    gen/train/clip_fraction         | 0.149       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.648      |
# |    gen/train/explained_variance    | 0.904       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | -0.0214     |
# |    gen/train/n_updates             | 25          |
# |    gen/train/policy_gradient_loss  | -0.0149     |
# |    gen/train/value_loss            | 0.0176      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.733    |
# |    disc/disc_acc_expert             | 0.511    |
# |    disc/disc_acc_gen                | 0.955    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.616    |
# |    disc/disc_proportion_expert_pred | 0.278    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.736    |
# |    disc/disc_acc_expert             | 0.526    |
# |    disc/disc_acc_gen                | 0.946    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.615    |
# |    disc/disc_proportion_expert_pred | 0.29     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.717    |
# |    disc/disc_acc_expert             | 0.497    |
# |    disc/disc_acc_gen                | 0.938    |
# |    disc/disc_entropy                | 0.683    |
# |    disc/disc_loss                   | 0.622    |
# |    disc/disc_proportion_expert_pred | 0.28     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.718    |
# |    disc/disc_acc_expert             | 0.487    |
# |    disc/disc_acc_gen                | 0.949    |
# |    disc/disc_entropy                | 0.681    |
# |    disc/disc_loss                   | 0.615    |
# |    disc/disc_proportion_expert_pred | 0.269    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.736    |
# |    disc/disc_acc_expert             | 0.514    |
# |    disc/disc_acc_gen                | 0.958    |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.611    |
# |    disc/disc_proportion_expert_pred | 0.278    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.723    |
# |    disc/disc_acc_expert             | 0.516    |
# |    disc/disc_acc_gen                | 0.93     |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.609    |
# |    disc/disc_proportion_expert_pred | 0.293    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.711    |
# |    disc/disc_acc_expert             | 0.491    |
# |    disc/disc_acc_gen                | 0.931    |
# |    disc/disc_entropy                | 0.679    |
# |    disc/disc_loss                   | 0.607    |
# |    disc/disc_proportion_expert_pred | 0.28     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.76     |
# |    disc/disc_acc_expert             | 0.574    |
# |    disc/disc_acc_gen                | 0.946    |
# |    disc/disc_entropy                | 0.678    |
# |    disc/disc_loss                   | 0.605    |
# |    disc/disc_proportion_expert_pred | 0.314    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.729    |
# |    disc/disc_acc_expert             | 0.515    |
# |    disc/disc_acc_gen                | 0.944    |
# |    disc/disc_entropy                | 0.68     |
# |    disc/disc_loss                   | 0.612    |
# |    disc/disc_proportion_expert_pred | 0.285    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 6        |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 44.4     |
# |    gen/rollout/ep_rew_wrapped_mean  | 271      |
# |    gen/time/fps                     | 3.97e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 4        |
# |    gen/time/total_timesteps         | 9.83e+04 |
# |    gen/train/approx_kl              | 0.0104   |
# |    gen/train/clip_fraction          | 0.0995   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.613   |
# |    gen/train/explained_variance     | 0.91     |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.006    |
# |    gen/train/n_updates              | 30       |
# |    gen/train/policy_gradient_loss   | -0.00681 |
# |    gen/train/value_loss             | 0.0162   |
# --------------------------------------------------
# round:  50%|█████     | 6/12 [00:56<00:54,  9.13s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 54.1        |
# |    gen/rollout/ep_rew_wrapped_mean | 276         |
# |    gen/time/fps                    | 3983        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 4           |
# |    gen/time/total_timesteps        | 114688      |
# |    gen/train/approx_kl             | 0.010424063 |
# |    gen/train/clip_fraction         | 0.0995      |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.613      |
# |    gen/train/explained_variance    | 0.91        |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.006       |
# |    gen/train/n_updates             | 30          |
# |    gen/train/policy_gradient_loss  | -0.00681    |
# ...
# round:  83%|████████▎ | 10/12 [01:30<00:17,  8.55s/it]
# -----------------------------------------------------
# | raw/                               |              |
# |    gen/rollout/ep_len_mean         | 500          |
# |    gen/rollout/ep_rew_mean         | 106          |
# |    gen/rollout/ep_rew_wrapped_mean | 283          |
# |    gen/time/fps                    | 4210         |
# |    gen/time/iterations             | 1            |
# |    gen/time/time_elapsed           | 3            |
# |    gen/time/total_timesteps        | 180224       |
# |    gen/train/approx_kl             | 0.0063048145 |
# |    gen/train/clip_fraction         | 0.0463       |
# |    gen/train/clip_range            | 0.2          |
# |    gen/train/entropy_loss          | -0.599       |
# |    gen/train/explained_variance    | 0.964        |
# |    gen/train/learning_rate         | 0.0004       |
# |    gen/train/loss                  | -0.0284      |
# |    gen/train/n_updates             | 50           |
# |    gen/train/policy_gradient_loss  | -0.00171     |
# |    gen/train/value_loss            | 0.0289       |
# -----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.729    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.458    |
# |    disc/disc_entropy                | 0.671    |
# |    disc/disc_loss                   | 0.613    |
# |    disc/disc_proportion_expert_pred | 0.771    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.727    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.454    |
# |    disc/disc_entropy                | 0.672    |
# |    disc/disc_loss                   | 0.616    |
# |    disc/disc_proportion_expert_pred | 0.773    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.737    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.475    |
# |    disc/disc_entropy                | 0.671    |
# |    disc/disc_loss                   | 0.61     |
# |    disc/disc_proportion_expert_pred | 0.763    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.73     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.461    |
# |    disc/disc_entropy                | 0.668    |
# |    disc/disc_loss                   | 0.61     |
# |    disc/disc_proportion_expert_pred | 0.77     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.736    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.473    |
# |    disc/disc_entropy                | 0.669    |
# |    disc/disc_loss                   | 0.607    |
# |    disc/disc_proportion_expert_pred | 0.764    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.738    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.477    |
# |    disc/disc_entropy                | 0.664    |
# |    disc/disc_loss                   | 0.601    |
# |    disc/disc_proportion_expert_pred | 0.762    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.742    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.483    |
# |    disc/disc_entropy                | 0.667    |
# |    disc/disc_loss                   | 0.602    |
# |    disc/disc_proportion_expert_pred | 0.758    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.731    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.463    |
# |    disc/disc_entropy                | 0.667    |
# |    disc/disc_loss                   | 0.604    |
# |    disc/disc_proportion_expert_pred | 0.769    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.734    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.468    |
# |    disc/disc_entropy                | 0.669    |
# |    disc/disc_loss                   | 0.608    |
# |    disc/disc_proportion_expert_pred | 0.766    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 11       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 106      |
# |    gen/rollout/ep_rew_wrapped_mean  | 283      |
# |    gen/time/fps                     | 4.21e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 3        |
# |    gen/time/total_timesteps         | 1.8e+05  |
# |    gen/train/approx_kl              | 0.00578  |
# |    gen/train/clip_fraction          | 0.051    |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.59    |
# |    gen/train/explained_variance     | 0.967    |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.00187  |
# |    gen/train/n_updates              | 55       |
# |    gen/train/policy_gradient_loss   | -0.00324 |
# |    gen/train/value_loss             | 0.0399   |
# --------------------------------------------------
# round:  92%|█████████▏| 11/12 [01:38<00:08,  8.43s/it]
# ----------------------------------------------------
# | raw/                               |             |
# |    gen/rollout/ep_len_mean         | 500         |
# |    gen/rollout/ep_rew_mean         | 114         |
# |    gen/rollout/ep_rew_wrapped_mean | 272         |
# |    gen/time/fps                    | 4230        |
# |    gen/time/iterations             | 1           |
# |    gen/time/time_elapsed           | 3           |
# |    gen/time/total_timesteps        | 196608      |
# |    gen/train/approx_kl             | 0.005777578 |
# |    gen/train/clip_fraction         | 0.051       |
# |    gen/train/clip_range            | 0.2         |
# |    gen/train/entropy_loss          | -0.59       |
# |    gen/train/explained_variance    | 0.967       |
# |    gen/train/learning_rate         | 0.0004      |
# |    gen/train/loss                  | 0.00187     |
# |    gen/train/n_updates             | 55          |
# |    gen/train/policy_gradient_loss  | -0.00324    |
# |    gen/train/value_loss            | 0.0399      |
# ----------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.592    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.185    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.671    |
# |    disc/disc_proportion_expert_pred | 0.908    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.604    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.208    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.668    |
# |    disc/disc_proportion_expert_pred | 0.896    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.603    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.205    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.669    |
# |    disc/disc_proportion_expert_pred | 0.897    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.61     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.22     |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.666    |
# |    disc/disc_proportion_expert_pred | 0.89     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.608    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.216    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.666    |
# |    disc/disc_proportion_expert_pred | 0.892    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.618    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.235    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.664    |
# |    disc/disc_proportion_expert_pred | 0.882    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.63     |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.261    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.663    |
# |    disc/disc_proportion_expert_pred | 0.87     |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | raw/                                |          |
# |    disc/disc_acc                    | 0.635    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.271    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.662    |
# |    disc/disc_proportion_expert_pred | 0.865    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# --------------------------------------------------
# --------------------------------------------------
# | mean/                               |          |
# |    disc/disc_acc                    | 0.612    |
# |    disc/disc_acc_expert             | 1        |
# |    disc/disc_acc_gen                | 0.225    |
# |    disc/disc_entropy                | 0.688    |
# |    disc/disc_loss                   | 0.666    |
# |    disc/disc_proportion_expert_pred | 0.888    |
# |    disc/disc_proportion_expert_true | 0.5      |
# |    disc/global_step                 | 12       |
# |    disc/n_expert                    | 1.02e+03 |
# |    disc/n_generated                 | 1.02e+03 |
# |    gen/rollout/ep_len_mean          | 500      |
# |    gen/rollout/ep_rew_mean          | 114      |
# |    gen/rollout/ep_rew_wrapped_mean  | 272      |
# |    gen/time/fps                     | 4.23e+03 |
# |    gen/time/iterations              | 1        |
# |    gen/time/time_elapsed            | 3        |
# |    gen/time/total_timesteps         | 1.97e+05 |
# |    gen/train/approx_kl              | 0.00725  |
# |    gen/train/clip_fraction          | 0.0748   |
# |    gen/train/clip_range             | 0.2      |
# |    gen/train/entropy_loss           | -0.581   |
# |    gen/train/explained_variance     | 0.97     |
# |    gen/train/learning_rate          | 0.0004   |
# |    gen/train/loss                   | 0.0103   |
# |    gen/train/n_updates              | 60       |
# |    gen/train/policy_gradient_loss   | -0.00504 |
# |    gen/train/value_loss             | 0.0429   |
# --------------------------------------------------
# round: 100%|██████████| 12/12 [01:46<00:00,  8.89s/it]

# %% [markdown]
# We can see that an untrained policy performs poorly, while GAIL matches expert returns (500):

# %%
print(
    "Rewards before training:",
    np.mean(learner_rewards_before_training),
    "+/-",
    np.std(learner_rewards_before_training),
)
print(
    "Rewards after training:",
    np.mean(learner_rewards_after_training),
    "+/-",
    np.std(learner_rewards_after_training),
)
# Out:
# Rewards before training: 102.6 +/- 24.11514047232568
# Rewards after training: 304.17 +/- 115.62093711780751
